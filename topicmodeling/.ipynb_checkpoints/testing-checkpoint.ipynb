# %%
# processing
import operator
from operator import methodcaller
import csv
import re
import numpy as np
import pandas as pd
from pprint import pprint
import string
import math
import itertools
import sqlite3
import copy

# gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import HdpModel
from gensim.models import TfidfModel

# nltk
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer

# plotting tools
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# C:\Users\thepe\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## R&R Corupus

# %%
# path to blacklisted tokens
blacklist = [t.strip() for t in next(csv.reader(open("tools\\blacklist.csv", 'r')))]

# levels of R&R terms considered
levels = [0, 1, 2, 3]

# format [term, orig, sentence, docID]
inPath = "raw.csv"
inFile = open(inPath, 'r')
inReader = csv.reader(inFile)


docTokens = dict()


next(inReader)
for inRow in inReader:
    term = inRow[0]
    sentence = inRow[2]
    docID = inRow[3]
    
    token = "_".join([t for t in term.split(":") if re.match(r'[^\W\d]*$', t) and not t in blacklist])
    
    level = token.count("_")
    
    if level in levels and not token in blacklist and len(token) > 0:
        print(token)
        if docID in docTokens:
            docTokens[docID] += [token]
        else:
            docTokens[docID] = [token]

docIDs = list(docTokens.keys())
texts = list(docTokens.values())

dictionary = corpora.Dictionary(texts)
print(len(dictionary))

dictionary.filter_extremes(no_below=1, no_above=1, keep_n=15000)
print(len(dictionary))

corpus = [dictionary.doc2bow(text) for text in texts]


tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]
# Out:
# symmetry_polyanion_minus
# minus
# symmetry_polyanion
# polyanion
# symmetry
# protonation_high_level
# high_level
# level
# protonation
# atom
# central_octahedron
# octahedron
# o_atom
# edge
# o_h
# h
# hydrogen_bond
# hydrogen
# bond
# unprotonated_protonated_ob_atom
# ob_atom
# crystal_structure_further_consolidation
# further_consolidation
# consolidation
# crystal_structure
# crystal
# structure
# extensive_o_h
# uncoordinated_water_molecule
# water_molecule
# water
# molecule
# independent_cation
# cation
# twofold_rotation_axis
# rotation_axis
# rotation
# axis
# sn_atom_geometry
# geometry
# sn_atom
# atom
# tetrahedral
# hydroxy_group
# group
# o_h
# h
# o_hydrogen_bond
# hydrogen_bond
# hydrogen
# bond
# molecule
# centrosymmetric_dimer
# dimer
# crystal_structure
# crystal_structure
# crystal
# structure
# metal_center_seven_coordinate
# metal_center
# metal
# center
# seven_coordinate
# coordinate
# coordinate
# approximate_pentagonal_bipyramidal_configuration
# ...

# %% [markdown]
# ## Unigrams Corpus

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) .union(string.digits)
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop and i not in blacklist])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized



# format [term, orig, sentence, docID]
inPath = "v1.csv"
inFile = open(inPath, 'r')
inReader = csv.reader(inFile)


docTokens = dict()

next(inReader)

for inRow in inReader:
    term = inRow[0]
    sentence = inRow[2]
    docID = inRow[3]
    
    if docID in docTokens:
        if sentence not in docTokens[docID]:
            docTokens[docID] += sentence
    else:
        docTokens[docID] = sentence

rawtext = docTokens.values()

testTexts = [clean(doc).split() for doc in rawtext] 
# build a dictionary for the text
testDict = corpora.Dictionary(testTexts)

# filter out terms that appear in fewer that LOW docs or greater than HIGH percent of docs and use KEEP terms
LOW = 1
HIGH = 0.25
KEEP = 17000


testDict.filter_extremes(no_below = LOW, no_above = HIGH, keep_n = KEEP)


# convert the text to a corpus with the dictionary
testCorpus = [testDict.doc2bow(text) for text in testTexts]

# %% [markdown]
# ## Bigrams Corpus

# %%
def double(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop and i not in blacklist])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    
    lastword = ""
    doubles = list()
    for word in normalized.split():
        if not lastword == "":
            doubles.append(lastword + "_" + word)
        lastword = word
    
    return " ".join(doubles)



doubleTexts = [double(doc).split()+clean(doc).split() for doc in rawtext]
# build a dictionary for the text
doubleDict = corpora.Dictionary(doubleTexts)

# filter out terms that appear in fewer that LOW docs or greater than HIGH percent of docs and use KEEP terms
LOW = 1
HIGH = 0.25
KEEP = 17000


doubleDict.filter_extremes(no_below = LOW, no_above = HIGH, keep_n = KEEP)


# convert the text to a corpus with the dictionary
doubleCorpus = [doubleDict.doc2bow(text) for text in doubleTexts]

# %% [markdown]
# ## Trigrams Corpus

# %%
def triple(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop and i not in blacklist])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    
    lastword = ""
    wordbefore = ""
    triples = list()
    for word in normalized.split():
        if not lastword == "" and not wordbefore == "":
            triples.append(wordbefore + "_" + lastword + "_" + word)
        wordbefore = lastword
        lastword = word
        
    
    return " ".join(triples)



tripleTexts = [triple(doc).split()+double(doc).split()+clean(doc).split() for doc in rawtext]
# build a dictionary for the text
tripleDict = corpora.Dictionary(tripleTexts)

# filter out terms that appear in fewer that LOW docs or greater than HIGH percent of docs and use KEEP terms
LOW = 1
HIGH = 0.25
KEEP = 17000


tripleDict.filter_extremes(no_below = LOW, no_above = HIGH, keep_n = KEEP)


# convert the text to a corpus with the dictionary
tripleCorpus = [tripleDict.doc2bow(text) for text in tripleTexts]
# Out:
# [['compound_knahptmoo_ho', 'knahptmoo_ho_contains', 'ho_contains_discrete', 'contains_discrete_hexamolybdoplatinateivhptmoo', 'discrete_hexamolybdoplatinateivhptmoo_minus', 'hexamolybdoplatinateivhptmoo_minus_polyanion', 'minus_polyanion_symmetry', 'polyanion_symmetry_highest', 'symmetry_highest_level', 'highest_level_protonationfive', 'level_protonationfive_atom', 'protonationfive_atom_central', 'atom_central_pto', 'central_pto_octahedron', 'pto_octahedron_mu', 'octahedron_mu_atom', 'mu_atom_oc', 'atom_oc_one', 'oc_one_atom', 'one_atom_outer', 'atom_outer_edgesharing', 'outer_edgesharing_moo', 'edgesharing_moo_octahedronthe', 'moo_octahedronthe_polyanions', 'octahedronthe_polyanions_connected', 'polyanions_connected_almost', 'connected_almost_linear', 'almost_linear_ho', 'linear_ho_hydrogen', 'ho_hydrogen_bond', 'hydrogen_bond_protonated', 'bond_protonated_unprotonated', 'protonated_unprotonated_ob', 'unprotonated_ob_atomsfurther', 'ob_atomsfurther_consolidation', 'atomsfurther_cons
# ...

# %%
def testRR(passes):
    
    model = gensim.models.LdaMulticore(corpus, 
                                       num_topics = 6,
                                       id2word=dictionary,
                                       passes=passes,
                                       workers = 8)
    
    coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_uci')
    
    return coherencemodel.get_coherence()

def testUni(passes):
    
    model = gensim.models.LdaMulticore(testCorpus, 
                                       num_topics = 6,
                                       id2word=testDict,
                                       passes=passes,
                                       workers = 8)
        

    coherencemodel = CoherenceModel(model=model, texts=testTexts, dictionary=testDict, coherence='c_uci')
    
    return coherencemodel.get_coherence()
    
    


def testBi(passes):
    
    model = gensim.models.LdaMulticore(doubleCorpus, 
                                       num_topics = 6,
                                       id2word=doubleDict,
                                       passes=passes,
                                       workers = 8)
        

    coherencemodel = CoherenceModel(model=model, texts=doubleTexts, dictionary=doubleDict, coherence='c_uci')
    
    return coherencemodel.get_coherence()
    
    
def testTri(passes):
    
    model = gensim.models.LdaMulticore(tripleCorpus, 
                                       num_topics = 6,
                                       id2word=tripleDict,
                                       passes=passes,
                                       workers = 8)
        

    coherencemodel = CoherenceModel(model=model, texts=tripleTexts, dictionary=tripleDict, coherence='c_uci')
    
    return coherencemodel.get_coherence()

# %% [markdown]
# ## Testing

# %%
passes = list(range(1, 11)) + [12, 14, 16, 18, 20, 23, 25, 28, 30, 35, 40, 45, 50]

for p in passes:
    print(p)
    
    RRRes = list()
    UniRes = list()
    BiRes = list()
    TriRes = list()
    
    
    for i in range(0, 10):
        RRRes.append(testRR(p))
        UniRes.append(testUni(p))
        BiRes.append(testBi(p))
        TriRes.append(testTri(p))
        
    RRaverage = sum(RRRes)/10
    Uniaverage = sum(UniRes)/10
    Biaverage = sum(BiRes)/10
    Triaverage = sum(TriRes)/10
    
    print(RRRes)
    print(UniRes)
    print(BiRes)
    print(TriRes)
    
    coh1.append(RRaverage)
    coh2.append(Uniaverage)
    coh3.append(Biaverage)
    coh4.append(Triaverage)
# Out:
# 1
# [-0.6411826004007315, -0.5667750260155455, -0.5881415100630443, -0.6402404186636904, -0.34920165219390387, -0.6922307355817107, -0.8696811584670948, -0.7637303995296604, -0.835970224729107, -0.6629586475487219]
# [-2.568105863234203, -2.415876077162889, -2.716072495992701, -2.9881702360457694, -2.731330373480754, -2.714976640924131, -2.416313059122807, -2.6908186475225464, -2.451772295628808, -2.5979118484577137]
# [-5.086017523380285, -4.580450611298813, -4.762598394026076, -5.546849244430519, -4.798722787452374, -4.839685683953622, -5.1417016305177965, -4.6201536519697965, -4.565739258749091, -4.91468867095963]
# [-5.5045303694457575, -5.778796106129746, -5.712518910861708, -5.844602613226716, -5.885145172846027, -5.444526415126489, -5.457805600019507, -6.248402007283464, -6.052663704059573, -5.558528448503746]
# 2
# ...

# %%
allpasses = list(range(1, 11)) + [12, 15, 18, 20, 22, 24, 26, 28, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 90, 100]


plt.plot(allpasses, coh1, 'r', label = "R&R")
plt.plot(allpasses, coh2, 'b', label = "Unigram")
plt.plot(allpasses, coh3, 'g', label = "Bigram")
plt.plot(allpasses, coh4, 'y', label = "Trigram")
plt.xlabel("Passes")
plt.ylabel("UCI Coherence Score")
plt.legend()
plt.show()

# %%
print(coh1)
print(coh2)
print(coh3)
print(coh4)
# Out:
# [-0.6903202944782785, -0.7253427072952017, -0.9395941215408634, -1.1508823826215253, -1.0912998731133583, -1.2073578945955892, -1.1060469586381723, -1.0863699188513316, -0.9419078642371662, -1.128491813504049, -0.9175852701745789, -1.1041159507619673, -0.9357171966274305, -1.3630997539759104, -1.0100125282117518, -1.0295430633277942, -1.0083216346005053, -1.3954233822408248, -1.4203407219290587, -1.4127423270468171, -1.3588846047717937, -1.4081891878123305, -0.9804149830236725, -1.6174477210599139, -1.11804242830759, -1.3604523764541405, -1.3378937088192688, -1.6815658523592725, -1.7131472848934108]
# ...

# %%
[-0.6789483428066678, -0.7799833810934375, -0.9272994970163829, -0.9119757170410308, -0.9148003702738989, -0.994628290547749, -0.9856101447818542, -1.1748479327152466, -1.121531717615296, -0.9002847197522558, -1.112475675142587, -1.141478048565626, -1.190960935805839, -1.196469911906366, -1.048131726239049, -1.3335526526344885, -1.241743326251489, -1.3460947134154138, -1.2465188092576258, -1.159480992937121, -1.1549752901364998]
[-2.088052106063871, -2.3497331694898347, -1.7940048324292612, -1.6864484366365056, -2.0148241187079097, -1.7943102403749607, -1.7996098064408954, -1.6314830654889803, -1.6688282734376803, -1.3850001519130424, -1.698037174147477, -1.551037073233228, -1.4776226744120966, -1.3683202796253524, -1.3059773061352176, -1.4337617629471988, -1.561353315044697, -1.4062066647093954, -1.6848984797378186, -1.7912814330522557, -1.5847283435442066]
